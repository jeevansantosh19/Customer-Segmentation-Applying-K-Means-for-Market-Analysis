# %%
# Importing the Required Libraries for Data Analysis and Manipulation
import numpy as np
import pandas as pd

# %%
# Uploading a Required Dataset
customer_data = pd.read_csv('Mall_Customers.csv')
customer_data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Checking the Information of a Dataset
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
# Getting the Dimensions of a Dataset
customer_data.shape
# Out:
# (200, 5)

# %%
# Displaying the First Rows of a Dataset
customer_data.head(10)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
# Displaying the Last Rows of a Dataset
customer_data.tail(10)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 190         191  Female   34                 103                      23
# 191         192  Female   32                 103                      69
# 192         193    Male   33                 113                       8
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
# Getting the columns of a Dataset
customer_data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
# Getting the Data Types of every column in a Dataset
customer_data.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
# Getting the Unique Values of a CustomerID
customer_data['CustomerID'].unique
# Out:
# <bound method Series.unique of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# Name: CustomerID, Length: 200, dtype: int64>

# %%
# Getting the Unique Values of a Age
customer_data['Age'].unique
# Out:
# <bound method Series.unique of 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64>

# %%
# Querying the particular column / columns
customer_data[['CustomerID','Age']]
# Out:
#      CustomerID  Age
# 0             1   19
# 1             2   21
# 2             3   20
# 3             4   23
# 4             5   31
# ..          ...  ...
# 195         196   35
# 196         197   45
# 197         198   32
# 198         199   32
# 199         200   30
#
# [200 rows x 2 columns]

# %%
# Grouping the CustomerID by Gender
customer_data.groupby('Gender')['Age'].sum()
# Out:
# Gender
# Female    4267
# Male      3503
# Name: Age, dtype: int64

# %%
# Pivot Table
customer_data.pivot_table(values = 'Age', index = 'Gender', aggfunc = 'sum')
# Out:
#          Age
# Gender
# Female  4267
# Male    3503

# %%
# Performing Correlation
corr_cust = customer_data[['Age','Annual Income (k$)']].corr()
corr_cust
# Out:
#                          Age  Annual Income (k$)
# Age                 1.000000           -0.012398
# Annual Income (k$) -0.012398            1.000000

# %%
# Perform the Aggregate Functions for Incomes
print("Incomes:")
print("Sum of Incomes:",customer_data['Annual Income (k$)'].sum())
print("Mean / Average of Incomes:",customer_data['Annual Income (k$)'].mean())
print("Count of Incomes:",customer_data['Annual Income (k$)'].count())
print("Maximum of Income:",customer_data['Annual Income (k$)'].max())
print("Minimum of Income:",customer_data['Annual Income (k$)'].min())
print("Variance of Incomes:",customer_data['Annual Income (k$)'].var())
print("Standard Deviation of Incomes:",customer_data['Annual Income (k$)'].std())

# Perform the Aggregate Functions for Ages
print("\nAges:")
print("Sum of Ages:",customer_data['Age'].sum())
print("Mean / Average of Ages:",customer_data['Age'].mean())
print("Count of Ages:",customer_data['Age'].count())
print("Maximum of Age:",customer_data['Age'].max())
print("Minimum of Age:",customer_data['Age'].min())
print("Variance of Ages:",customer_data['Age'].var())
print("Standard Deviation of Ages:",customer_data['Age'].std())

# Perform the Aggregate Functions for Ages
print("\nSpending Score:")
print("Sum of Spending Scores:",customer_data['Spending Score (1-100)'].sum())
print("Mean / Average of Spending Scores:",customer_data['Spending Score (1-100)'].mean())
print("Count of Spending Scores:",customer_data['Spending Score (1-100)'].count())
print("Maximum of Spending Score:",customer_data['Spending Score (1-100)'].max())
print("Minimum of Spending Score:",customer_data['Spending Score (1-100)'].min())
print("Variance of Spending Scores:",customer_data['Spending Score (1-100)'].var())
print("Standard Deviation of Spending Scores:",customer_data['Spending Score (1-100)'].std())
# Out:
# Incomes:
# Sum of Incomes: 12112
# Mean / Average of Incomes: 60.56
# Count of Incomes: 200
# Maximum of Income: 137
# Minimum of Income: 15
# Variance of Incomes: 689.8355778894472
# Standard Deviation of Incomes: 26.264721165271244
#
# Ages:
# Sum of Ages: 7770
# Mean / Average of Ages: 38.85
# Count of Ages: 200
# Maximum of Age: 70
# Minimum of Age: 18
# Variance of Ages: 195.13316582914572
# Standard Deviation of Ages: 13.96900733155888
#
# Spending Score:
# Sum of Spending Scores: 10040
# Mean / Average of Spending Scores: 50.2
# Count of Spending Scores: 200
# Maximum of Spending Score: 99
# Minimum of Spending Score: 1
# Variance of Spending Scores: 666.8542713567839
# Standard Deviation of Spending Scores: 25.823521668370173

# %%
# Checking the Inconsistencies of a Dataset
customer_data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Encoding the Text Values
import sklearn
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
# Encoding the Gender (Male = 0, Female = 1)
customer_data['Gender'] = le.fit_transform(customer_data['Gender'])
customer_data['Gender']
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 195    0
# 196    0
# 197    1
# 198    1
# 199    1
# Name: Gender, Length: 200, dtype: int32

# %%
# Preprocessing the Numerical Columns
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()
mms
# Out:
# MinMaxScaler()

# %%
# Scaling the Numerical Columns
customer_data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']] = mms.fit_transform(customer_data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])
customer_data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)
# 0    0.019231            0.000000                0.387755
# 1    0.057692            0.000000                0.816327
# 2    0.038462            0.008197                0.051020
# 3    0.096154            0.008197                0.775510
# 4    0.250000            0.016393                0.397959
# ..        ...                 ...                     ...
# 195  0.326923            0.860656                0.795918
# 196  0.519231            0.909836                0.275510
# 197  0.269231            0.909836                0.744898
# 198  0.269231            1.000000                0.173469
# 199  0.230769            1.000000                0.836735
#
# [200 rows x 3 columns]

# %%
customer_data
# Out:
#      CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       1  0.019231            0.000000                0.387755
# 1             2       1  0.057692            0.000000                0.816327
# 2             3       0  0.038462            0.008197                0.051020
# 3             4       0  0.096154            0.008197                0.775510
# 4             5       0  0.250000            0.016393                0.397959
# ..          ...     ...       ...                 ...                     ...
# 195         196       0  0.326923            0.860656                0.795918
# 196         197       0  0.519231            0.909836                0.275510
# 197         198       1  0.269231            0.909836                0.744898
# 198         199       1  0.269231            1.000000                0.173469
# 199         200       1  0.230769            1.000000                0.836735
#
# [200 rows x 5 columns]

# %%
# Unsupervised Machine Learning (K Means)
from sklearn.cluster import KMeans

# %%
# Dropping the 'CustomerID' column
dataset1 = customer_data.drop('CustomerID', axis = 1)
dataset1
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0         1  0.019231            0.000000                0.387755
# 1         1  0.057692            0.000000                0.816327
# 2         0  0.038462            0.008197                0.051020
# 3         0  0.096154            0.008197                0.775510
# 4         0  0.250000            0.016393                0.397959
# ..      ...       ...                 ...                     ...
# 195       0  0.326923            0.860656                0.795918
# 196       0  0.519231            0.909836                0.275510
# 197       1  0.269231            0.909836                0.744898
# 198       1  0.269231            1.000000                0.173469
# 199       1  0.230769            1.000000                0.836735
#
# [200 rows x 4 columns]

# %%
# Feature Selection
X = dataset1[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
X
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)
# 0    0.019231            0.000000                0.387755
# 1    0.057692            0.000000                0.816327
# 2    0.038462            0.008197                0.051020
# 3    0.096154            0.008197                0.775510
# 4    0.250000            0.016393                0.397959
# ..        ...                 ...                     ...
# 195  0.326923            0.860656                0.795918
# 196  0.519231            0.909836                0.275510
# 197  0.269231            0.909836                0.744898
# 198  0.269231            1.000000                0.173469
# 199  0.230769            1.000000                0.836735
#
# [200 rows x 3 columns]

# %%
# Initializing K Means
k_means = KMeans(n_clusters = 5, random_state = 42)
k_means
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# Training the KMeans
k_means.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# Elbow Method
wcss = []
for i in range(2, 6):
    k_means = KMeans(n_clusters = i, random_state = 42)
    k_means.fit(X)
    wcss.append(k_means.inertia_)

wcss
# Out:
# [22.56077488260975, 17.55965836843309, 14.879180410647209, 10.438008966122696]

# %%
# Creating a Column named 'Cluster'
dataset1['Cluster'] = k_means.fit_predict(X)
dataset1
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0         1  0.019231            0.000000                0.387755        4
# 1         1  0.057692            0.000000                0.816327        4
# 2         0  0.038462            0.008197                0.051020        2
# 3         0  0.096154            0.008197                0.775510        4
# 4         0  0.250000            0.016393                0.397959        4
# ..      ...       ...                 ...                     ...      ...
# 195       0  0.326923            0.860656                0.795918        1
# 196       0  0.519231            0.909836                0.275510        3
# 197       1  0.269231            0.909836                0.744898        1
# 198       1  0.269231            1.000000                0.173469        3
# 199       1  0.230769            1.000000                0.836735        1
#
# [200 rows x 5 columns]

# %%
# Importing the Required libraries for Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Visualizing the Elbow Method
plt.figure(figsize = (12,12))
plt.plot(range(2, 6), wcss, marker = '*')
plt.title("Customer Segmentation")
plt.xlabel("Number Of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
# Visualizing the Scatter Plot for Clusters
plt.figure(figsize=(12,12))

# Get unique cluster labels
clusters = dataset1['Cluster'].unique()

# Define a color map manually (optional)
colors = plt.cm.rainbow(np.linspace(0, 1, len(clusters)))

# Plot each cluster separately
for i, cluster in enumerate(clusters):
    cluster_data = dataset1[dataset1['Cluster'] == cluster]
    plt.scatter(cluster_data['Annual Income (k$)'],
                cluster_data['Spending Score (1-100)'],
                color=colors[i],
                label=f'Cluster {cluster}')

plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1 - 100)')
plt.title("Customer Segmentation Using K Means")
plt.legend()
plt.show()

# %%
# Evaluating the Metrics
from sklearn.metrics import silhouette_score

kmeans_ss = silhouette_score(X, k_means.labels_)
print("\nSilhouette Score:", kmeans_ss)
# Out:
# Silhouette Score: 0.40421034059490324

# %%
# Importing the Required Libraries for Serialization
import pickle

# %%
# Saving the Model
with open('model/kmeans_model.pkl', 'wb') as file:
    pickle.dump({'model': k_means, 'score': kmeans_ss}, file)
